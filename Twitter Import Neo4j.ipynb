# %%
import os
import time
import requests
import urllib
from neo4j.v1 import GraphDatabase, basic_auth

neo4jUrl = os.environ.get('NEO4J_URL',"bolt://localhost")
neo4jUser = os.environ.get('NEO4J_USER',"neo4j")
neo4jPass = os.environ.get('NEO4J_PASSWORD',"test")
bearerToken = os.environ.get('TWITTER_BEARER',"")

if len(bearerToken) == 0 : 
    raise(Exception("No Twitter Bearer token configured"))
    
driver = GraphDatabase.driver(neo4jUrl, auth=basic_auth(neo4jUser, neo4jPass))

session = driver.session()

# Add uniqueness constraints.
session.run( "CREATE CONSTRAINT ON (t:Tweet) ASSERT t.id IS UNIQUE;")
session.run( "CREATE CONSTRAINT ON (u:User) ASSERT u.screen_name IS UNIQUE;")
session.run( "CREATE CONSTRAINT ON (h:Tag) ASSERT h.name IS UNIQUE;")
session.run( "CREATE CONSTRAINT ON (l:Link) ASSERT l.url IS UNIQUE;")

# %%
# Build query.
importQuery = """
UNWIND {tweets} AS t

WITH t
ORDER BY t.id

WITH t,
     t.entities AS e,
     t.user AS u,
     t.retweeted_status AS retweet

MERGE (tweet:Tweet {id:t.id})
SET tweet:Content, tweet.text = t.text,
    tweet.created = t.created_at,
    tweet.favorites = t.favorite_count

MERGE (user:User {screen_name:u.screen_name})
SET user.name = u.name,
    user.location = u.location,
    user.followers = u.followers_count,
    user.following = u.friends_count,
    user.statuses = u.statuses_count,
    user.profile_image_url = u.profile_image_url

MERGE (user)-[:POSTED]->(tweet)

FOREACH (h IN e.hashtags |
  MERGE (tag:Tag {name:LOWER(h.text)})
  MERGE (tag)<-[:TAGGED]-(tweet)
)

FOREACH (u IN e.urls |
  MERGE (url:Link {url:u.expanded_url})
  MERGE (tweet)-[:LINKED]->(url)
)

FOREACH (m IN e.user_mentions |
  MERGE (mentioned:User {screen_name:m.screen_name})
  ON CREATE SET mentioned.name = m.name
  MERGE (tweet)-[:MENTIONED]->(mentioned)
)

FOREACH (r IN [r IN [t.in_reply_to_status_id] WHERE r IS NOT NULL] |
  MERGE (reply_tweet:Tweet {id:r})
  MERGE (tweet)-[:REPLIED_TO]->(reply_tweet)
)

FOREACH (retweet_id IN [x IN [retweet.id] WHERE x IS NOT NULL] |
    MERGE (retweet_tweet:Tweet {id:retweet_id})
    MERGE (tweet)-[:RETWEETED]->(retweet_tweet)
)
"""

# %%
# todo as params
q = urllib.quote_plus(os.environ.get("TWITTER_SEARCH",'NHS'))
maxPages = 100
catch_up = False
count = 100
result_type = "recent"
lang = "en"

since_id = -1
max_id = -1
page = 1

hasMore = True
while hasMore and page <= maxPages:
    if catch_up:
        result = session.run("MATCH (t:Tweet:Content) RETURN max(t.id) as sinceId")
        for record in result:
            if record["sinceId"] != None:
                since_id = record["sinceId"]
    else:
        result = session.run("MATCH (t:Tweet:Content) RETURN min(t.id) as maxId")
        for record in result:
            if record["maxId"] != None:
                max_id = record["maxId"]

    # Build URL.
    apiUrl = "https://api.twitter.com/1.1/search/tweets.json?q=%s&count=%s&result_type=%s&lang=%s" % (q, count, result_type, lang)
    if since_id != -1 :
        apiUrl += "&since_id=%s" % (since_id)
    if max_id != -1 :
        apiUrl += "&max_id=%s" % (max_id)
    # print(apiUrl)
    response = requests.get(apiUrl, headers = {"accept":"application/json","Authorization":"Bearer " + bearerToken})
    if response.status_code <> 200:
        raise(Exception(response.status_code, response.text))
        
    json = response.json()
    meta = json["search_metadata"]
    # print(meta)
    tweets = json.get("statuses",[])    
    # print(len(tweets))
    if len(tweets) > 0:
        result = session.run(importQuery,{"tweets":tweets})
        print(result.consume().counters)
        page = page + 1
    else:
        hasMore = False
        
    print("more {more} page {page} max_id {max_id}".format(more=hasMore,page=page,max_id=max_id))
    time.sleep(1)
#    if json.get('quota_remaining',0) <= 0:
#        time.sleep(10)
    if json.get('backoff',None) != None:
        print("backoff",json['backoff'])
        time.sleep(json['backoff']+5)
# Out:
# {'labels_added': 306, 'nodes_created': 207, 'properties_set': 1123, 'relationships_created': 359}
# more True page 2 max_id 818830663260323841
# {'labels_added': 318, 'nodes_created': 219, 'properties_set': 1139, 'relationships_created': 356}
# more True page 3 max_id 818830033674469376
# {'labels_added': 323, 'nodes_created': 224, 'properties_set': 1140, 'relationships_created': 372}
# more True page 4 max_id 818829500381331456
# {'labels_added': 342, 'nodes_created': 243, 'properties_set': 1168, 'relationships_created': 356}
# more True page 5 max_id 818828930970951680
# {'labels_added': 332, 'nodes_created': 233, 'properties_set': 1161, 'relationships_created': 365}
# more True page 6 max_id 818828442070228992
# {'labels_added': 334, 'nodes_created': 235, 'properties_set': 1152, 'relationships_created': 397}
# more True page 7 max_id 818827913017565186
# {'labels_added': 311, 'nodes_created': 212, 'properties_set': 1126, 'relationships_created': 371}
# more True page 8 max_id 818827437291278336
# {'labels_added': 321, 'nodes_created': 222, 'properties_set': 1143, 'relationships_created': 386}
# more True page 9 max_id 818826921186299904
# {'labels_added': 321, 'nodes_created': 222, 'properties_set': 1143, 'relationships_created': 362}
# more True page 10 max_id 818826378699296768
# {'labels_added': 326, 'nodes_created': 227, 'properties_set': 1150, 'relationships_created': 381}
# more True page 11 max_id 818825811746656257
# {'labels_added': 329, 'nodes_created': 230, 'properties_set': 1147, 'relationships_created': 362}
# more True page 12 max_id 818825281528037378
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1120, 'relationships_created': 339}
# more True page 13 max_id 818824701854224384
# {'labels_added': 318, 'nodes_created': 219, 'properties_set': 1134, 'relationships_created': 326}
# more True page 14 max_id 818824244519989249
# {'labels_added': 358, 'nodes_created': 259, 'properties_set': 1184, 'relationships_created': 358}
# more True page 15 max_id 818823796786429952
# {'labels_added': 320, 'nodes_created': 221, 'properties_set': 1139, 'relationships_created': 360}
# more True page 16 max_id 818823390417092608
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1123, 'relationships_created': 352}
# more True page 17 max_id 818822948056399878
# {'labels_added': 323, 'nodes_created': 224, 'properties_set': 1149, 'relationships_created': 367}
# more True page 18 max_id 818822445062823936
# {'labels_added': 325, 'nodes_created': 226, 'properties_set': 1149, 'relationships_created': 378}
# more True page 19 max_id 818821965679132676
# {'labels_added': 308, 'nodes_created': 209, 'properties_set': 1117, 'relationships_created': 337}
# more True page 20 max_id 818821512534822917
# {'labels_added': 302, 'nodes_created': 203, 'properties_set': 1120, 'relationships_created': 361}
# more True page 21 max_id 818821038037405697
# {'labels_added': 325, 'nodes_created': 226, 'properties_set': 1144, 'relationships_created': 357}
# more True page 22 max_id 818820643013742592
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1117, 'relationships_created': 336}
# more True page 23 max_id 818820254155624449
# {'labels_added': 305, 'nodes_created': 206, 'properties_set': 1115, 'relationships_created': 332}
# more True page 24 max_id 818819870859010049
# {'labels_added': 337, 'nodes_created': 238, 'properties_set': 1155, 'relationships_created': 337}
# more True page 25 max_id 818819511495311361
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1117, 'relationships_created': 348}
# more True page 26 max_id 818818981481938944
# {'labels_added': 291, 'nodes_created': 192, 'properties_set': 1102, 'relationships_created': 328}
# more True page 27 max_id 818818551767269376
# {'labels_added': 321, 'nodes_created': 222, 'properties_set': 1139, 'relationships_created': 357}
# more True page 28 max_id 818818065328697345
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1117, 'relationships_created': 381}
# more True page 29 max_id 818817611467198465
# {'labels_added': 308, 'nodes_created': 209, 'properties_set': 1121, 'relationships_created': 320}
# more True page 30 max_id 818817153822498816
# {'labels_added': 312, 'nodes_created': 213, 'properties_set': 1130, 'relationships_created': 396}
# more True page 31 max_id 818816760115826688
# {'labels_added': 320, 'nodes_created': 221, 'properties_set': 1143, 'relationships_created': 359}
# more True page 32 max_id 818816256220528640
# {'labels_added': 228, 'nodes_created': 129, 'properties_set': 1033, 'relationships_created': 373}
# more True page 33 max_id 818815754111946752
# {'labels_added': 314, 'nodes_created': 215, 'properties_set': 1134, 'relationships_created': 372}
# more True page 34 max_id 818815276686934016
# {'labels_added': 320, 'nodes_created': 221, 'properties_set': 1133, 'relationships_created': 324}
# more True page 35 max_id 818814803317850112
# {'labels_added': 317, 'nodes_created': 218, 'properties_set': 1139, 'relationships_created': 363}
# more True page 36 max_id 818814377830862848
# {'labels_added': 332, 'nodes_created': 233, 'properties_set': 1147, 'relationships_created': 343}
# more True page 37 max_id 818813972384219136
# {'labels_added': 319, 'nodes_created': 220, 'properties_set': 1141, 'relationships_created': 368}
# more True page 38 max_id 818813552022712320
# {'labels_added': 309, 'nodes_created': 210, 'properties_set': 1124, 'relationships_created': 367}
# more True page 39 max_id 818813149541498881
# {'labels_added': 317, 'nodes_created': 218, 'properties_set': 1134, 'relationships_created': 363}
# more True page 40 max_id 818812649030950913
# {'labels_added': 311, 'nodes_created': 212, 'properties_set': 1122, 'relationships_created': 335}
# more True page 41 max_id 818812210092920833
# {'labels_added': 308, 'nodes_created': 209, 'properties_set': 1116, 'relationships_created': 342}
# more True page 42 max_id 818811830072213504
# {'labels_added': 320, 'nodes_created': 221, 'properties_set': 1136, 'relationships_created': 378}
# more True page 43 max_id 818811434859634688
# {'labels_added': 330, 'nodes_created': 231, 'properties_set': 1145, 'relationships_created': 362}
# more True page 44 max_id 818811050325749760
# {'labels_added': 346, 'nodes_created': 247, 'properties_set': 1156, 'relationships_created': 327}
# more True page 45 max_id 818810736851841026
# {'labels_added': 327, 'nodes_created': 228, 'properties_set': 1146, 'relationships_created': 366}
# more True page 46 max_id 818810449470902274
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1124, 'relationships_created': 353}
# more True page 47 max_id 818810080976060417
# {'labels_added': 310, 'nodes_created': 211, 'properties_set': 1121, 'relationships_created': 347}
# more True page 48 max_id 818809716331728900
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1121, 'relationships_created': 359}
# more True page 49 max_id 818809374613217281
# {'labels_added': 317, 'nodes_created': 218, 'properties_set': 1134, 'relationships_created': 339}
# more True page 50 max_id 818808998694703106
# {'labels_added': 343, 'nodes_created': 244, 'properties_set': 1165, 'relationships_created': 377}
# more True page 51 max_id 818808587048861697
# {'labels_added': 291, 'nodes_created': 192, 'properties_set': 1097, 'relationships_created': 328}
# more True page 52 max_id 818808226984628225
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1124, 'relationships_created': 346}
# more True page 53 max_id 818807807571017728
# {'labels_added': 337, 'nodes_created': 238, 'properties_set': 1153, 'relationships_created': 345}
# more True page 54 max_id 818807437625069568
# {'labels_added': 298, 'nodes_created': 199, 'properties_set': 1113, 'relationships_created': 354}
# more True page 55 max_id 818807118904037377
# {'labels_added': 306, 'nodes_created': 207, 'properties_set': 1123, 'relationships_created': 332}
# more True page 56 max_id 818806768688123904
# {'labels_added': 280, 'nodes_created': 181, 'properties_set': 1089, 'relationships_created': 309}
# more True page 57 max_id 818806444254498816
# {'labels_added': 323, 'nodes_created': 224, 'properties_set': 1147, 'relationships_created': 336}
# more True page 58 max_id 818806100871024640
# {'labels_added': 340, 'nodes_created': 241, 'properties_set': 1167, 'relationships_created': 369}
# more True page 59 max_id 818805653955342336
# {'labels_added': 312, 'nodes_created': 213, 'properties_set': 1125, 'relationships_created': 338}
# more True page 60 max_id 818805023010390021
# {'labels_added': 299, 'nodes_created': 200, 'properties_set': 1114, 'relationships_created': 351}
# more True page 61 max_id 818804528057303040
# {'labels_added': 323, 'nodes_created': 224, 'properties_set': 1148, 'relationships_created': 382}
# more True page 62 max_id 818804016985542656
# {'labels_added': 308, 'nodes_created': 209, 'properties_set': 1119, 'relationships_created': 350}
# more True page 63 max_id 818803510284320768
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1125, 'relationships_created': 354}
# more True page 64 max_id 818803055529492480
# {'labels_added': 306, 'nodes_created': 207, 'properties_set': 1125, 'relationships_created': 348}
# more True page 65 max_id 818802633871855618
# {'labels_added': 298, 'nodes_created': 199, 'properties_set': 1108, 'relationships_created': 337}
# more True page 66 max_id 818802224662974468
# {'labels_added': 310, 'nodes_created': 211, 'properties_set': 1125, 'relationships_created': 339}
# more True page 67 max_id 818801733996515329
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1121, 'relationships_created': 377}
# more True page 68 max_id 818801241916633088
# {'labels_added': 294, 'nodes_created': 195, 'properties_set': 1102, 'relationships_created': 346}
# more True page 69 max_id 818800793159667713
# {'labels_added': 301, 'nodes_created': 202, 'properties_set': 1115, 'relationships_created': 343}
# more True page 70 max_id 818800308432338945
# {'labels_added': 300, 'nodes_created': 201, 'properties_set': 1117, 'relationships_created': 350}
# more True page 71 max_id 818799759314055168
# {'labels_added': 277, 'nodes_created': 178, 'properties_set': 1094, 'relationships_created': 325}
# more True page 72 max_id 818799333663539200
# {'labels_added': 303, 'nodes_created': 204, 'properties_set': 1122, 'relationships_created': 339}
# more True page 73 max_id 818798970038341634
# {'labels_added': 276, 'nodes_created': 177, 'properties_set': 1088, 'relationships_created': 344}
# more True page 74 max_id 818798562242953217
# {'labels_added': 335, 'nodes_created': 236, 'properties_set': 1160, 'relationships_created': 376}
# more True page 75 max_id 818798188903759872
# {'labels_added': 297, 'nodes_created': 198, 'properties_set': 1112, 'relationships_created': 345}
# more True page 76 max_id 818797718621528068
# {'labels_added': 272, 'nodes_created': 173, 'properties_set': 1083, 'relationships_created': 320}
# more True page 77 max_id 818797246003249152
# {'labels_added': 282, 'nodes_created': 183, 'properties_set': 1091, 'relationships_created': 365}
# more True page 78 max_id 818796855727390721
# {'labels_added': 305, 'nodes_created': 206, 'properties_set': 1122, 'relationships_created': 351}
# more True page 79 max_id 818796339077255170
# {'labels_added': 287, 'nodes_created': 188, 'properties_set': 1097, 'relationships_created': 359}
# more True page 80 max_id 818795789619171328
# {'labels_added': 298, 'nodes_created': 199, 'properties_set': 1119, 'relationships_created': 361}
# more True page 81 max_id 818795294519336960
# {'labels_added': 296, 'nodes_created': 197, 'properties_set': 1112, 'relationships_created': 368}
# more True page 82 max_id 818794787071467521
# {'labels_added': 289, 'nodes_created': 190, 'properties_set': 1104, 'relationships_created': 346}
# more True page 83 max_id 818794262397677568
# {'labels_added': 283, 'nodes_created': 184, 'properties_set': 1099, 'relationships_created': 353}
# more True page 84 max_id 818793721558863872
# {'labels_added': 300, 'nodes_created': 201, 'properties_set': 1112, 'relationships_created': 327}
# more True page 85 max_id 818793223435014145
# {'labels_added': 305, 'nodes_created': 206, 'properties_set': 1121, 'relationships_created': 352}
# more True page 86 max_id 818792635502653441
# {'labels_added': 296, 'nodes_created': 197, 'properties_set': 1111, 'relationships_created': 358}
# more True page 87 max_id 818792094848479232
# {'labels_added': 317, 'nodes_created': 218, 'properties_set': 1136, 'relationships_created': 358}
# more True page 88 max_id 818791523072536576
# {'labels_added': 294, 'nodes_created': 195, 'properties_set': 1108, 'relationships_created': 347}
# more True page 89 max_id 818790774196371457
# {'labels_added': 295, 'nodes_created': 196, 'properties_set': 1103, 'relationships_created': 354}
# more True page 90 max_id 818790296242819072
# {'labels_added': 297, 'nodes_created': 198, 'properties_set': 1107, 'relationships_created': 327}
# more True page 91 max_id 818789794255880192
# {'labels_added': 304, 'nodes_created': 205, 'properties_set': 1124, 'relationships_created': 355}
# more True page 92 max_id 818789352910323713
# {'labels_added': 295, 'nodes_created': 196, 'properties_set': 1104, 'relationships_created': 348}
# more True page 93 max_id 818788696711426048
# {'labels_added': 296, 'nodes_created': 197, 'properties_set': 1110, 'relationships_created': 369}
# more True page 94 max_id 818788084229820417
# {'labels_added': 307, 'nodes_created': 208, 'properties_set': 1124, 'relationships_created': 392}
# more True page 95 max_id 818787483974598659
# {'labels_added': 301, 'nodes_created': 202, 'properties_set': 1112, 'relationships_created': 362}
# more True page 96 max_id 818786910080561152
# {'labels_added': 296, 'nodes_created': 197, 'properties_set': 1109, 'relationships_created': 346}
# more True page 97 max_id 818786334592630786
# {'labels_added': 296, 'nodes_created': 197, 'properties_set': 1112, 'relationships_created': 348}
# more True page 98 max_id 818785861387124736
# {'labels_added': 289, 'nodes_created': 190, 'properties_set': 1100, 'relationships_created': 335}
# more True page 99 max_id 818785347337338882
# {'labels_added': 312, 'nodes_created': 213, 'properties_set': 1122, 'relationships_created': 362}
# more True page 100 max_id 818784763641270272
# {'labels_added': 298, 'nodes_created': 199, 'properties_set': 1112, 'relationships_created': 330}
# more True page 101 max_id 818784202439163904

# %%
session.close()
